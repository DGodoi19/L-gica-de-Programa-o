# %%
nota=int(input("Nota do estudante: ")) #Daniel Godoi ALves Watrin
pcdf=float(input("Porcentagem de presença: "))
if nota>7:
  print("Aprovado!")

elif nota>=6:
  if pcdf>= 75:
    print("Aprovado!")
  else:
    print("Reprovado")

else:
  print("Reprovado")
# Out:
# Nota do estudante: 2
# Porcentagem de faltas: 100
# Reprovado

# %%
print("Daniel") #Daniel Godoi ALves Watrin
# Out:
# Daniel

# %%
n=input("Digite seu primeiro nome e sobrenome:") #Daniel Godoi ALves Watrin
print(n)
# Out:
# Digite seu primeiro nome e sobrenome:Daniel Godoi
# Daniel Godoi

# %%
print('''
|       |
 |     |
  |   |
   | |
    |
   | |
  |   |
 |     |
|       |
''') #Daniel Godoi ALves Watrin
# Out:
#
# |       |
#  |     |
#   |   |
#    | |
#     |
#    | |
#   |   |
#  |     |
# |       |

# %%
dia_hj = 31 #Daniel Godoi ALves Watrin
mes_hj = 3

dia = int(input("Digite o do seu aniversário: "))
mes = int(input('Digite o mês do seu aniversário: '))

if mes == 3:
    qt_dias = 31 - dia

    if qt_dias == 0:
        print("Feliz aniversário!")
    else:
        print(f"Passaram {qt_dias} dias do seu aniversário.")
elif mes == 2:
    qt_dias = 31 + 28 - dia
    print(f"Passaram {qt_dias} dias do seu aniversário.")
elif mes == 1:
    qt_dias = 31 + 28 + 31 - dia
    print(f"Passaram {qt_dias} dias do seu aniversário.")
elif mes == 4:
    qt_dias = dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
elif mes == 5:
    qt_dias = 30 + dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
elif mes == 6:
    qt_dias = 30 + 31 + dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
elif mes == 7:
    qt_dias = 30 + 31 + 30 + dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
elif mes == 8:
    qt_dias = 30 + 31 + 30 + 31+ dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
elif mes == 9:
    qt_dias = 30 + 31 + 30 + 31 + 31 + dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
elif mes == 10:
    qt_dias = 30 + 31 + 30 + 31 + 31 + 30 + dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
elif mes == 11:
    qt_dias = 30 + 31 + 30 + 31 + 31 + 30 + 31 + dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
elif mes == 12:
    qt_dias = 30 + 31 + 30 + 31 + 31 + 30 + 31 + 30 + dia
    print(f"Faltam {qt_dias} dias para o seu seu aniversário.")
# Out:
# Qual é o dia do seu aniversário? 31
# Qual o mês do seu aniversário? 3
# Qual é o dia atual? 1
# Qual é o mês atual? 4
# Faltam  30 dias e 1 meses para seu aniversário

# %%
po=float(input("Qual o valor original do produto? ")) #Daniel Godoi ALves Watrin
d= po/100 * 20
pcd= po/100 * 80

print(f"""              | Preço original: |  Desconto: |  Preço com desconto: |
               ================ ============ ======================
              |     {po}       |     {d}    |          {pcd}       |

]                                                           """)
# Out:
# Qual o valor original do produto? 100
#                |Preço original: |  Desconto: |  Preço com desconto: |
#                ================ ============ ======================
#               |     100.0       |     20.0    |          80.0       |
#
# ]

# %%
po=float(input("Qual o valor original do produto? ")) #Daniel Godoi ALves Watrin
de=float(input("Qual a porcentagem de desconto? "))
d= po/100 * de
pcd= po-d
print("O preço original", po ,"com a porcentagem de desconto", de,"receberá em reais o desconto de", d, "totalizando o valor de", pcd,)
# Out:
# Qual o valor original do produto? 300
# Qual a porcentagem de desconto? 20
# O preço original 300.0 com a porcentagem de desconto 20.0 receberá em reais o desconto de 60.0 totalizando o valor de 240.0

# %%
v1=int(input("Digite o valor 1:")) #Daniel Godoi ALves Watrin
v2=int(input("Digite o valor 2:"))
v3=int(input("Digite o valor 3:"))
vm= (v1+v2+v3)/3
print(" A média aritmética desses valores é: ", vm,)
# Out:
# Digite o valor 1:20
# Digite o valor 2:30
# Digite o valor 3:10
#  A média aritmética desses valores é:  20.0

# %%
v1=float(input("Digite o valor 1:")) #Daniel Godoi ALves Watrin
v2=float(input("Digite o valor 2:"))
v3=float(input("Digite o valor 3:"))
v4=float(input("Digite o valor 4:"))
vm= (v1+v2+v3+v4)/4
vmg= (v1*v2*v3*v4)**(1/4)
vmh= 4/(1/v1 + 1/v2 + 1/v3 + 1/v4)
if v1>0 and v2>0 and v3>0 and v4> 0:
  print(" A média aritmética desses valores é: ", vm,"a média geométrica é:", vmg, " a média harmônica é: ", vmh,)
else:
  print("precisa de valores positivos")
# Out:
# Digite o valor 1:10
# Digite o valor 2:-20
# Digite o valor 3:30
# Digite o valor 4:40
# precisa de valores positivos

# %%
v1=float(input("Digite o valor 1:")) #Daniel Godoi ALves Watrin
v2=float(input("Digite o valor 2:"))
v3=float(input("Digite o valor 3:"))
v4=float(input("Digite o valor 4:"))
vm= (v1+v2+v3+v4)/4
va= ((v1-vm)**2)+ ((v2-vm)**2) + ((v3-vm)**2) + ((v4-vm)**2)/(4)
dv= va**1/2
print("média= ", vm ,"variancia= ", va ,"desvio padrão= ", dv)#dablio
# Out:
# Digite o valor 1:10
# Digite o valor 2:20
# Digite o valor 3:30
# Digite o valor 4:40
# média=  25.0 variancia=  331.25 desvio padrão=  165.625

# %%
v1=int(input("Digite o valor 1: ")) #Daniel Godoi ALves Watrin
v2=int(input("Digite o valor 2: "))
v3=int(input("Digite o valor 3: "))

if v1>v2 and v1>v3:
  print("O maior número é: ", v1)
elif v2>v1 and v2>v3:
  print("O maior número é: ", v2)
else:
  print("O maior número é: ", v3)
# Out:
# Digite o valor 1: 20
# Digite o valor 2: 30
# Digite o valor 3: 40
# O maior número é:  40

# %%
v1=int(input("Digite o valor 1: ")) #Daniel Godoi ALves Watrin
v2=int(input("Digite o valor 2: "))
v3=int(input("Digite o valor 3: "))

if v1>v2>v3:
  print(v3, v2, v1)
elif v1>v3>v2:
  print(v2,v3,v1)
elif v2>v1>v3:
  print(v3, v1, v2)
elif v2>v3>v1:
  print(v1, v3, v2)
elif v3>v2>v1:
  print(v1, v2, v3)
else:
  print(v2, v1, v3)
# Out:
# Digite o valor 1: 10
# Digite o valor 2: 20
# Digite o valor 3: 30
# 10 20 30

# %%
l1=input("Informe a letra: ") .lower() #Daniel Godoi ALves Watrin
l2=input("Informe a letra: ") .lower()
l3=input("Informe a letra: ") .lower()
if l1>l2>l3:
  print(l3, l2, l1)
elif l1>l3>l2:
  print(l2,l3,l1)
elif l2>l1>l3:
  print(l3, l1, l2)
elif l2>l3>l1:
  print(l1, l3, l2)
elif l3>l2>l1:
  print(l1, l2, l3)
else:
  print(l2, l1,l3)
# Out:
# Informe a letra: ad
# Informe a letra: ab
# Informe a letra: ac
# ab ac ad

# %%
sexo=input("Informe o seu sexo: ") #Daniel Godoi ALves Watrin
peso=float(input("Informe seu peso: "))
altura=float(input("Informe sua altura: "))

idade=int(input("Informe sua idade: "))

TMBH = 66.47 + (13.75 * peso) + (5.003 * altura) - (6.755 * idade)
TMBM = 655.09 + (9.563 * peso) + (1.85 * altura) - (4.676 * idade)

if sexo=="masculino":
  print("Sua taxa metabólica basal como homem é: ", TMBH)
else:
  print("Sua taxa metabólica basal como mulher é: ", TMBM)
# Out:
# Informe o seu sexo: masculino
# Informe seu peso: 95
# Informe sua altura: 1.83
# Informe sua idade: 25
# Sua taxa metabólica basal como homem é:  1213.0004900000001

# %%
n=int(input("Informe um número")) #Daniel Godoi ALves Watrin

if n==1:
  print('''1x1=1
  1x2=2
  1x3=3
  1x4=4
  1x5=5
  1x6=6
  1x7=7
  1x8=8
  1x9=9
  1x10=10''')
elif n==2:
  print('''2x1=2
  2x3=6
  2x4=8
  2x5=10
  2x6=12
  2x7=14
  2x8=16
  2x9=18
  2x10=20''')
elif n==3:
  print('''3x1=3
  3x2=6
  3x3=9
  3x4=12
  3x5=15
  3x6=18
  3x7=21
  3x8=24
  3x9=27
  3x10=30''')
elif n==4:
  print('''4x1=4
  4x2=8
  4x3=12
  4x4=16
  4x5=20
  4x6=24
  4x7=28
  4x8=32
  4x9=36
  4x10=40''')
elif n==5:
  print('''5x1=5
  5x2=10
  5x3=15
  5x4=20
  5x5=25
  5x6=30
  5x7=35
  5x8=40
  5x9=45
  5x10=50''')
elif n==6:
  print('''6x1=6
  6x2=12
  6x3=18
  6x4=24
  6x5=30
  6x6=36
  6x7=42
  6x8=48
  6x9=54
  6x10=60''')
elif n==7:
  print('''7x0=0
  7x1=7
  7x2=14
  7x3=21
  7x4=28
  7x5=35
  7x6=42
  7x7=49
  7x8=56
  7x9=63
  7x10=70''')
elif n==8:
  print('''8x1=8
  8x2=16
  8x3=24
  8x4=32
  8x5=40
  8x6=48
  8x7=56
  8x8=64
  8x9=72
  8x10=80''')
elif n==9:
  print('''9x1=9
  9x2=18
  9x3= 27
  9x4=36
  9x5=45
  9x6=54
  9x7=63
  9x8=72
  9x9=81
  9x10=90''')
else:
  print('''10x1=10
  10x2=20
  10x3=30
  10x4=40
  10x5=50
  10x6=60
  10x7=70
  10x8=80
  10x9=90
  10x10=100''')
# Out:
# Informe um número7
# 7x0=0
#   7x1=7
#   7x2=14
#   7x3=21
#   7x4=28
#   7x5=35
#   7x6=42
#   7x7=49
#   7x8=56
#   7x9=63
#   7x10=70
